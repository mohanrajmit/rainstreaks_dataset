# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/rainstreaks_dataset/blob/main/rainstreak_modeltraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy==1.19.5
# Out:
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 2.1 MB/s
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# tensorflow 2.8.0 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.19.5

# %%
# !git clone https://github.com/mohanrajmit/rainstreaks_dataset.git
# Out:
# Cloning into 'rainstreaks_dataset'...
# remote: Enumerating objects: 13514, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 13514 (delta 3), reused 8 (delta 2), pack-reused 13502
# Receiving objects: 100% (13514/13514), 776.67 MiB | 13.83 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Checking out files: 100% (13503/13503), done.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
cd /content/rainstreaks_dataset
# Out:
# /content/rainstreaks_dataset

# %%
import os
import re
import random
import numpy as np
import tensorflow as tf
import matplotlib.image as img
import matplotlib.pyplot as plt
from GuidedFilter import guided_filter
import time

# %%
##################### Select GPU device ####################################
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
############################################################################

#tf.reset_default_graph()

##################### Network parameters ###################################
num_feature = 16             # number of feature maps
num_channels = 3             # number of input's channels 
patch_size = 64              # patch size 
KernelSize = 3               # kernel size 
learning_rate = 0.1          # learning rate
iterations = int(2.1*1e5)    # iterations
batch_size = 20              # batch size
save_model_path = "./model/" # saved model's path
model_name = 'model-epoch'   # saved model's name
############################################################################


input_path = "/content/rainstreaks_dataset/rainy_image"    # the path of rainy images
gt_path = "/content/rainstreaks_dataset/ground_truth"       # the path of ground truth


input_files = os.listdir(input_path)
gt_files = os.listdir(gt_path)

# %%
len(input_files)
# Out:
# 12600

# %%
 
# randomly select image patches
def _parse_function(filename, label):  
     
  image_string = tf.io.read_file(filename)  
  image_decoded = tf.image.decode_jpeg(image_string, channels=3)  
  rainy = tf.cast(image_decoded, tf.float32)/255.0
  
  
  image_string = tf.io.read_file(label)  
  image_decoded = tf.image.decode_jpeg(image_string, channels=3)  
  label = tf.cast(image_decoded, tf.float32)/255.0

  t = time.time()
  rainy = tf.image.random_crop(rainy, [patch_size, patch_size ,3],seed = t)   # randomly select patch
  label = tf.image.random_crop(label, [patch_size, patch_size ,3],seed = t)   
  return rainy, label

# %%
# network structure
def inference(images, is_training):
    regularizer = tf.contrib.layers.l2_regularizer(scale = 1e-10)
    initializer = tf.contrib.layers.xavier_initializer()

    base = guided_filter(images, images, 15, 1, nhwc=True) # using guided filter for obtaining base layer
    detail = images - base   # detail layer

   #  layer 1
    with tf.variable_scope('layer_1'):
         output = tf.layers.conv2d(detail, num_feature, KernelSize, padding = 'same', kernel_initializer = initializer, 
                                   kernel_regularizer = regularizer, name='conv_1')
         output = tf.layers.batch_normalization(output, training=is_training, name='bn_1')
         output_shortcut = tf.nn.relu(output, name='relu_1')
  
   #  layers 2 to 25
    for i in range(12):
        with tf.variable_scope('layer_%d'%(i*2+2)):	
             output = tf.layers.conv2d(output_shortcut, num_feature, KernelSize, padding='same', kernel_initializer = initializer, 
                                       kernel_regularizer = regularizer, name=('conv_%d'%(i*2+2)))
             output = tf.layers.batch_normalization(output, training=is_training, name=('bn_%d'%(i*2+2)))	
             output = tf.nn.relu(output, name=('relu_%d'%(i*2+2)))


        with tf.variable_scope('layer_%d'%(i*2+3)): 
             output = tf.layers.conv2d(output, num_feature, KernelSize, padding='same', kernel_initializer = initializer,
                                       kernel_regularizer = regularizer, name=('conv_%d'%(i*2+3)))
             output = tf.layers.batch_normalization(output, training=is_training, name=('bn_%d'%(i*2+3)))
             output = tf.nn.relu(output, name=('relu_%d'%(i*2+3)))

        output_shortcut = tf.add(output_shortcut, output)   # shortcut

   # layer 26
    with tf.variable_scope('layer_26'):
         output = tf.layers.conv2d(output_shortcut, num_channels, KernelSize, padding='same',   kernel_initializer = initializer, 
                                   kernel_regularizer = regularizer, name='conv_26')
         neg_residual = tf.layers.batch_normalization(output, training=is_training, name='bn_26')

    final_out = tf.add(images, neg_residual)

    return final_out

# %%
from typing import Counter
if __name__ == '__main__':   
   RainName = list(os.listdir(input_path))
   RainName.sort()
   rainname=[]
   for i in range(len(RainName)):
      rainname.append(input_path +"/" + RainName[i])
  
    
      
   LabelName = list(os.listdir(gt_path))
   LabelName.sort(reverse=True)

   #rainname.sort(reverse=True)
   
   print(rainname)
     
   #counter=0
   final_lst=[]
   for i in range(len(LabelName)):
     for j in range(14):
       final_lst.append(gt_path +"/"+ LabelName[i])

       #counter+=1
  
   #final_lst.sort(reverse=True)
   print(final_lst)
   filename_tensor = tf.convert_to_tensor(rainname, dtype=tf.string)  
   labels_tensor = tf.convert_to_tensor(final_lst, dtype=tf.string)  
   #labels_tensor = tf.convert_to_tensor(LabelName, dtype=tf.string)  
   dataset = tf.data.Dataset.from_tensor_slices((filename_tensor, labels_tensor))
   dataset = dataset.map(_parse_function)    
   dataset = dataset.prefetch(buffer_size=batch_size * 10)
   dataset = dataset.batch(batch_size).repeat()  
   iterator = dataset.make_one_shot_iterator()
   #tf.compat.v1.data
   
   rainy, labels = iterator.get_next()     
   
   
   outputs = inference(rainy, is_training = True)
   loss = tf.reduce_mean(tf.square(labels - outputs))    # MSE loss

   
   lr_ = learning_rate
   lr = tf.placeholder(tf.float32 ,shape = [])  

   update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
   with tf.control_dependencies(update_ops):
        train_op =  tf.train.MomentumOptimizer(lr, 0.9).minimize(loss) 

   
   all_vars = tf.trainable_variables()   
   g_list = tf.global_variables()
   bn_moving_vars = [g for g in g_list if 'moving_mean' in g.name]
   bn_moving_vars += [g for g in g_list if 'moving_variance' in g.name]
   all_vars += bn_moving_vars
   print("Total parameters' number: %d" %(np.sum([np.prod(v.get_shape().as_list()) for v in all_vars])))  
   saver = tf.train.Saver(var_list=all_vars, max_to_keep=5)
   
   
   config = tf.ConfigProto()
   config.gpu_options.per_process_gpu_memory_fraction = 0.8 # GPU setting
   config.gpu_options.allow_growth = True
   init =  tf.group(tf.global_variables_initializer(), 
                         tf.local_variables_initializer())  
    
   with tf.Session(config=config) as sess:      
      with tf.device('/gpu:0'): 
            sess.run(init)
            tf.get_default_graph().finalize()
            
            if tf.train.get_checkpoint_state('./model/'):   # load previous trained models
               ckpt = tf.train.latest_checkpoint('./model/')
               saver.restore(sess, ckpt)
               ckpt_num = re.findall(r'(\w*[0-9]+)\w*',ckpt)
               start_point = int(ckpt_num[0]) + 1   
               print("successfully load previous model")
       
            else:   # re-training if no previous trained models
               start_point = 0    
               print("re-training")
    
    
            check_data, check_label = sess.run([rainy, labels])
            print("Check patch pair:")  
            '''plt.subplot(1,2,1)     
            plt.imshow(check_data[0,:,:,:])
            plt.title('input')         
            plt.subplot(1,2,2)    
            plt.imshow(check_label[0,:,:,:])
            plt.title('ground truth')        
            plt.show()'''
    
    
            start = time.time()  
            
            for j in range(start_point,iterations):   #  iterations
                if j+1 > int(1e5):
                    lr_ = learning_rate*0.1
                if j+1 > int(2e5):
                    lr_ = learning_rate*0.01             
                    
    
                _,Training_Loss = sess.run([train_op,loss], feed_dict={lr: lr_}) # training
          
                if np.mod(j+1,100) == 0 and j != 0: # save the model every 100 iterations
                   end = time.time()              
                   print ('%d / %d iteraions, learning rate = %.3f, Training Loss = %.4f, runtime = %.1f s' 
                          % (j+1, iterations, lr_, Training_Loss, (end - start)))                  
                   save_path_full = os.path.join(save_model_path, model_name) # save model
                   saver.save(sess, save_path_full, global_step = j+1, write_meta_graph=False)
                   start = time.time()
                   
            print('Training is finished.')
   sess.close()
# Out:
# ['/content/rainstreaks_dataset/rainy_image/100_1.jpg', '/content/rainstreaks_dataset/rainy_image/100_10.jpg', '/content/rainstreaks_dataset/rainy_image/100_11.jpg', '/content/rainstreaks_dataset/rainy_image/100_12.jpg', '/content/rainstreaks_dataset/rainy_image/100_13.jpg', '/content/rainstreaks_dataset/rainy_image/100_14.jpg', '/content/rainstreaks_dataset/rainy_image/100_2.jpg', '/content/rainstreaks_dataset/rainy_image/100_3.jpg', '/content/rainstreaks_dataset/rainy_image/100_4.jpg', '/content/rainstreaks_dataset/rainy_image/100_5.jpg', '/content/rainstreaks_dataset/rainy_image/100_6.jpg', '/content/rainstreaks_dataset/rainy_image/100_7.jpg', '/content/rainstreaks_dataset/rainy_image/100_8.jpg', '/content/rainstreaks_dataset/rainy_image/100_9.jpg', '/content/rainstreaks_dataset/rainy_image/101_1.jpg', '/content/rainstreaks_dataset/rainy_image/101_10.jpg', '/content/rainstreaks_dataset/rainy_image/101_11.jpg', '/content/rainstreaks_dataset/rainy_image/101_12.jpg', '/content/rainstreaks_dataset/rainy_image/101_13.jpg', '/content/rainstreaks_dataset/rainy_image/101_14.jpg', '/content/rainstreaks_dataset/rainy_image/101_2.jpg', '/content/rainstreaks_dataset/rainy_image/101_3.jpg', '/content/rainstreaks_dataset/rainy_image/101_4.jpg', '/content/rainstreaks_dataset/rainy_image/101_5.jpg', '/content/rainstreaks_dataset/rainy_image/101_6.jpg', '/content/rainstreaks_dataset/rainy_image/101_7.jpg', '/content/rainstreaks_dataset/rainy_image/101_8.jpg', '/content/rainstreaks_dataset/rainy_image/101_9.jpg', '/content/rainstreaks_dataset/rainy_image/102_1.jpg', '/content/rainstreaks_dataset/rainy_image/102_10.jpg', '/content/rainstreaks_dataset/rainy_image/102_11.jpg', '/content/rainstreaks_dataset/rainy_image/102_12.jpg', '/content/rainstreaks_dataset/rainy_image/102_13.jpg', '/content/rainstreaks_dataset/rainy_image/102_14.jpg', '/content/rainstreaks_dataset/rainy_image/102_2.jpg', '/content/rainstreaks_dataset/rainy_image/102_3.jpg', '/content/rainstreaks_dataset/rainy_image/102_4.jpg', '/content/rainstreaks_dataset/rainy_image/102_5.jpg', '/content/rainstreaks_dataset/rainy_image/102_6.jpg', '/content/rainstreaks_dataset/rainy_image/102_7.jpg', '/content/rainstreaks_dataset/rainy_image/102_8.jpg', '/content/rainstreaks_dataset/rainy_image/102_9.jpg', '/content/rainstreaks_dataset/rainy_image/103_1.jpg', '/content/rainstreaks_dataset/rainy_image/103_10.jpg', '/content/rainstreaks_dataset/rainy_image/103_11.jpg', '/content/rainstreaks_dataset/rainy_image/103_12.jpg', '/content/rainstreaks_dataset/rainy_image/103_13.jpg', '/content/rainstreaks_dataset/rainy_image/103_14.jpg', '/content/rainstreaks_dataset/rainy_image/103_2.jpg', '/content/rainstreaks_dataset/rainy_image/103_3.jpg', '/content/rainstreaks_dataset/rainy_image/103_4.jpg', '/content/rainstreaks_dataset/rainy_image/103_5.jpg', '/content/rainstreaks_dataset/rainy_image/103_6.jpg', '/content/rainstreaks_dataset/rainy_image/103_7.jpg', '/content/rainstreaks_dataset/rainy_image/103_8.jpg', '/content/rainstreaks_dataset/rainy_image/103_9.jpg', '/content/rainstreaks_dataset/rainy_image/104_1.jpg', '/content/rainstreaks_dataset/rainy_image/104_10.jpg', '/content/rainstreaks_dataset/rainy_image/104_11.jpg', '/content/rainstreaks_dataset/rainy_image/104_12.jpg', '/content/rainstreaks_dataset/rainy_image/104_13.jpg', '/content/rainstreaks_dataset/rainy_image/104_14.jpg', '/content/rainstreaks_dataset/rainy_image/104_2.jpg', '/content/rainstreaks_dataset/rainy_image/104_3.jpg', '/content/rainstreaks_dataset/rainy_image/104_4.jpg', '/content/rainstreaks_dataset/rainy_image/104_5.jpg', '/content/rainstreaks_dataset/rainy_image/104_6.jpg', '/content/rainstreaks_dataset/rainy_image/104_7.jpg', '/content/rainstreaks_dataset/rainy_image/104_8.jpg', '/content/rainstreaks_dataset/rainy_image/104_9.jpg', '/content/rainstreaks_dataset/rainy_image/105_1.jpg', '/content/rainstreaks_dataset/rainy_image/105_10.jpg', '/content/rainstreaks_dataset/rainy_image/105_11.jpg', '/content/rainstreaks_dataset/ ...
# ['/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/99.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/98.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/97.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/96.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/95.jpg', '/content/rainstreaks_dataset/ground_truth/94.jpg', '/content/rainstreaks_dataset/ground_truth/94.jpg', '/content/rainstreaks_dataset/ground_truth/94.jpg', '/content/rainstreaks_dataset/ground_truth/94.jpg', '/content/rainstreaks_dataset/ground_truth/94.jpg', '/content/rainstreaks_dataset/ground_truth/94.jpg', '/content/rainstreaks_dataset/ground_truth/94.j ...
# WARNING:tensorflow:Entity <function _parse_function at 0x7f4b3ecea830> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Str'
# WARNING: Entity <function _parse_function at 0x7f4b3ecea830> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Str'
# WARNING:tensorflow:From <ipython-input-8-4a39ac396483>:35: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/rainstreaks_dataset/GuidedFilter.py:49: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# WARNING:tensorflow:From /content/rainstreaks_dataset/GuidedFilter.py:51: The name tf.assert_greater is deprecated. Please use tf.compat.v1.assert_greater instead.
#
# WARNING:tensorflow:From <ipython-input-7-5e1b95d493f6>:12: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-7-5e1b95d493f6>:13: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# Total parameters' number: 58175
# re-training
# Check patch pair:
# 100 / 210000 iteraions, learning rate = 0.100, Training Loss = 0.1028, runtime = 15.7 s
# 200 / 210000 iteraions, learning rate = 0.100, Training Loss = 0.0720, runtime = 14.7 s
